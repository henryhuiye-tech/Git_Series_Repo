# %%
# This is a new file and our first commit 


# This is our code 

print("I love Git")

# This is a change for our code starting in branch_for_josh 
print("I love merging and branching.")
